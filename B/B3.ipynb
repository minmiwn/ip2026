# %%
# %load_ext autoreload
# %autoreload 2

# %%
import cv2 
import numpy as np
import matplotlib.pyplot as plt
from moduleAdjust import manual_cal_hist, normalization, cdf, equalization, bw

# %%
iname = '/home/chou/Project/ImageProcessing/study/self-study/image/kat.png'
img = cv2.imread(iname, 0)
plt.imshow(img, cmap='gray')

# %%
hist = manual_cal_hist(img)
thres1 = bw(img, 80)
thres2 = bw(img, 120)
thres3 = bw(img, 160)

plt.figure()
plt.bar(range(256), hist)
plt.xlabel("Gray Level")
plt.ylabel("Frequency")
plt.title("Histogram")
plt.show()

plt.figure(figsize=(10, 5))
plt.subplot(1, 3, 1)
plt.imshow(thres1, cmap='gray')
plt.title("Threshole 80")
plt.axis('off')

plt.subplot(1, 3, 2)
plt.imshow(thres2, cmap='gray')
plt.title("Threshole 120")
plt.axis('off')

plt.subplot(1, 3, 3)
plt.imshow(thres3, cmap='gray')
plt.title("Threshole 160")
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(1151.5), np.float64(2047.5), np.float64(-0.5))
